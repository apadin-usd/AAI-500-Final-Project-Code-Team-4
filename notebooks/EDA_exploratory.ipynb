# %% [markdown]
# # EDA: House Prices Initial analysis:
# The following Jupyter notebook would analyze the housing data. After initial EDA performed by marquise; using a correlation matrix its a statistical way to determine the strenght of the price of the house with each of the features. Therefore, this jupyter notebook would do the following: <br>
#
# - Determine the heatmap of all features.
# - Select the features with a correlation higher than 0.4

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Step 2: Load Housing Dataset - Load the housing price dataset, inspect the first few rows and check for missing values.

# %%
#Set the data path to the data folder
data_path = os.path.join(os.getcwd(), os.pardir, "data", "housing.csv")

# Load housing dataset
df_data = pd.read_csv(data_path)
df_data.head()
print(df_data.shape)
# Out:
# (545, 13)

# %%
### NOW LETS do the following, lets replace the binary variables to numbers 
# single binomial bernoulli counts
df_data["mainroad"] = df_data["mainroad"].replace({"yes": 1, "no": 0})
df_data["guestroom"] = df_data["guestroom"].replace({"yes": 1, "no": 0})
df_data["basement"] = df_data["basement"].replace({"yes": 1, "no": 0})
df_data["hotwaterheating"] = df_data["hotwaterheating"].replace({"yes": 1, "no": 0})
df_data["airconditioning"] = df_data["airconditioning"].replace({"yes": 1, "no": 0})
df_data["parking"] = df_data["parking"].replace({"yes": 1, "no": 0})
df_data["prefarea"] = df_data["prefarea"].replace({"yes": 1, "no": 0})
df_data["furnishingstatus"] = df_data["furnishingstatus"].replace({"furnished": 1, "semi-furnished": 1, "unfurnished": 0})
# Out:
# C:\Users\ajedr\AppData\Local\Temp\ipykernel_27212\2117601333.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_data["mainroad"] = df_data["mainroad"].replace({"yes": 1, "no": 0})
# C:\Users\ajedr\AppData\Local\Temp\ipykernel_27212\2117601333.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_data["guestroom"] = df_data["guestroom"].replace({"yes": 1, "no": 0})
# C:\Users\ajedr\AppData\Local\Temp\ipykernel_27212\2117601333.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_data["basement"] = df_data["basement"].replace({"yes": 1, "no": 0})
# C:\Users\ajedr\AppData\Local\Temp\ipykernel_27212\2117601333.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_data["hotwaterheating"] = df_data["hotwaterheating"].replace({"yes": 1, "no": 0})
# C:\Users\ajedr\AppData\Local\Temp\ipykernel_27212\2117601333.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_data["airconditioning"] = df_data["airconditioning"].replace({"yes": 1, "no": 0})
# C:\Users\ajedr\AppData\Local\Temp\ipykernel_27212\2117601333.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_data["prefarea"] = df_data["prefarea"].replace({"yes": 1, "no": 0})
# C:\Users\ajedr\AppData\Local\Temp\ipykernel_27212\2117601333.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_data["furnishingstatus"] = df_data["furnishingstatus"].replace({"furnished": 1, "semi-furnished": 1, "unfurnished": 0})

# %%
# Check for null values and data types
print(df_data.info())  # Shows the data types, non-null counts
print(df_data.isnull().sum())  # Check for any missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    int64
#  6   guestroom         545 non-null    int64
#  7   basement          545 non-null    int64
#  8   hotwaterheating   545 non-null    int64
#  9   airconditioning   545 non-null    int64
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    int64
#  12  furnishingstatus  545 non-null    int64
# dtypes: int64(13)
# memory usage: 55.5 KB
# None
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
# Get summary statistics for the numerical columns
print(df_data.describe())  # Basic statistics for numerical columns
# Visualize the pairwise relationships between numerical features
sns.pairplot(df_data)
plt.show()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#          mainroad   guestroom    basement  hotwaterheating  airconditioning  \
# count  545.000000  545.000000  545.000000       545.000000       545.000000
# mean     0.858716    0.177982    0.350459         0.045872         0.315596
# std      0.348635    0.382849    0.477552         0.209399         0.465180
# min      0.000000    0.000000    0.000000         0.000000         0.000000
# 25%      1.000000    0.000000    0.000000         0.000000         0.000000
# 50%      1.000000    0.000000    0.000000         0.000000         0.000000
# 75%      1.000000    0.000000    1.000000         0.000000         1.000000
# max      1.000000    1.000000    1.000000         1.000000         1.000000
#
#           parking    prefarea  furnishingstatus
# count  545.000000  545.000000        545.000000
# mean     0.693578    0.234862          0.673394
# std      0.861586    0.424302          0.469402
# min      0.000000    0.000000          0.000000
# 25%      0.000000    0.000000          0.000000
# 50%      0.000000    0.000000          1.000000
# 75%      1.000000    0.000000          1.000000
# max      3.000000    1.000000          1.000000

# %%
### Create a correlation matrix
correlation_matrix = df_data.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
