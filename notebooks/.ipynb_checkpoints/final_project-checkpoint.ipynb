# %% [markdown]
# # Introduction

# %% [markdown]
# This project aims to develop a robust predictive model for estimating housing prices based on key features like property size, location, and number of rooms. By leveraging statistical analysis and modeling techniques, we explore the relationships between various property characteristics and their impact on market value. The resulting model will serve as a reliable, data-driven valuation tool, providing valuable insights for the real estate industry to estimate property prices with precision

# %% [markdown]
# The *Housing Price Prediction*$\text{}^{1}$ dataset observed provides key features for predicting house prices, including area, bedrooms, bathrooms, stories, amenities like air conditioning and parking, and information on furnishing status. It enables analysis and modeling to understand the factors impacting house prices and develop accurate predictions in real estate markets.

# %% [markdown]
# # Library Imports

# %%
# Import necessary libraries
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# # Data Loading and Initial Overview

# %%
# Data import
housing_raw = pd.read_csv('housing.csv')

# %%
# Explore first five items of the data
housing_raw.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# shape of the data; (rows, columns)
housing_raw.shape
# Out:
# (545, 13)

# %%
# Statistical description of the data
housing_raw.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# # Data Cleaning and Preparation

# %%
# removes any row with at least one missing value
housing = housing_raw.dropna()

# Replace categorical features
# housing['mainroad'] = housing['mainroad'].replace({'yes': 1, 'no': 0})
# housing['guestroom'] = housing['guestroom'].replace({'yes': 1, 'no': 0})
# housing['basement'] = housing['basement'].replace({'yes': 1, 'no': 0})
# housing['hotwaterheating'] = housing['hotwaterheating'].replace({'yes': 1, 'no': 0})
# housing['airconditioning'] = housing['airconditioning'].replace({'yes': 1, 'no': 0})
# housing['parking'] = housing['parking'].replace({'yes': 1, 'no': 0})
# housing['prefarea'] = housing['prefarea'].replace({'yes': 1, 'no': 0})
# housing['furnishingstatus'] = housing['furnishingstatus'].replace({'furnished': 2, 'semi-furnished': 1, 'unfurnished': 0})

housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# #  Exploratory Data Analysis

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# First plot - Histogram with KDE
sns.histplot(housing['price'], bins=30, kde=True, ax=axs[0])
axs[0].set_title('House Prices Distribution')
axs[0].set_xlabel('Price $1M')

# Second plot - Boxplot
sns.boxplot(x='price', data=housing, ax=axs[1])
axs[1].set_title('House Prices')
axs[1].set_ylabel('Price $1M')

plt.tight_layout()  # adjusts the spacing of histograms
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a 3x4 grid for 12 variables
fig, axs = plt.subplots(3, 4, figsize=(16, 12))

# First row of plots
axs[0, 0].hist(housing['area'], bins=10)
axs[0, 0].set_title('Area')

axs[0, 1].hist(housing['bedrooms'], bins=10)
axs[0, 1].set_title('Bedrooms')

axs[0, 2].hist(housing['bathrooms'], bins=10)
axs[0, 2].set_title('Bathrooms')

axs[0, 3].hist(housing['stories'], bins=10)
axs[0, 3].set_title('Stories')

# Second row of plots
axs[1, 0].hist(housing['mainroad'], bins=4)
axs[1, 0].set_title('Main Road')

axs[1, 1].hist(housing['guestroom'], bins=10)
axs[1, 1].set_title('Guestroom')

axs[1, 2].hist(housing['basement'], bins=4)
axs[1, 2].set_title('Basement')

axs[1, 3].hist(housing['hotwaterheating'], bins=4)
axs[1, 3].set_title('Hot Water Heating')

# Third row of plots
axs[2, 0].hist(housing['airconditioning'], bins=4)
axs[2, 0].set_title('Air Conditioning')

axs[2, 1].hist(housing['parking'], bins=10)
axs[2, 1].set_title('Parking')

axs[2, 2].hist(housing['prefarea'], bins=4)
axs[2, 2].set_title('Preferred Area')

axs[2, 3].hist(housing['furnishingstatus'], bins=6)
axs[2, 3].set_title('Furnishing Status')

# Adjust layout for better spacing
plt.tight_layout()

# Display the plots
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,12))        

# replace categorical features
housing['mainroad'] = housing['mainroad'].replace({'yes': 1, 'no': 0})
housing['guestroom'] = housing['guestroom'].replace({'yes': 1, 'no': 0})
housing['basement'] = housing['basement'].replace({'yes': 1, 'no': 0})
housing['hotwaterheating'] = housing['hotwaterheating'].replace({'yes': 1, 'no': 0})
housing['airconditioning'] = housing['airconditioning'].replace({'yes': 1, 'no': 0})
housing['parking'] = housing['parking'].replace({'yes': 1, 'no': 0})
housing['prefarea'] = housing['prefarea'].replace({'yes': 1, 'no': 0})
housing['furnishingstatus'] = housing['furnishingstatus'].replace({'furnished': 2, 'semi-furnished': 1, 'unfurnished': 0})
# correlation heatmap
sns.heatmap(housing.corr(), annot=True)

plt.show()

# %% [markdown]
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
# &nbsp;
#
#
# ----------------
# $^{1}$ Harishkumar Datalab. (2022). Housing price prediction. Kaggle. https://www.kaggle.com/datasets/harishkumardatalab/housing-price-prediction
